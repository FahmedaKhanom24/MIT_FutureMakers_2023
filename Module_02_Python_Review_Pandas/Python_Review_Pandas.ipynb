# %% [markdown]
# <a href="https://colab.research.google.com/github/MySureStart/SureStart_Summer_2023/blob/main/Module_04_Python_Review_Pandas/Python_Review_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import random

np.random.seed(0)
random.seed(0)

# %% [markdown]
# # Pandas
#
# Pandas is an open-source Python library that is used for **data manipulation, analysis, and visualization**. It provides data structures for efficiently storing and manipulating large datasets, and includes tools for data cleaning, data transformation, and data analysis.
#
# The two primary data structures provided by Pandas are Series and DataFrame.
#
# Pandas is widely used in data analysis and data science, as it provides a convenient and efficient way to work with **large datasets**. It is also often used in conjunction with other libraries, such as NumPy, Matplotlib, and Scikit-learn, to perform advanced data analysis and machine learning tasks.

# %% [markdown]
# ## Series
#
# A Series is a **one-dimensional labeled array** that can hold data of any type (integer, float, string, etc.). A Series is similar to a column in a spreadsheet or a SQL table.
#
# To create a Series in Pandas, you can use the `pd.Series()` function. Here's an example

# %%
# Create a Series of integers
my_series = pd.Series([10, 20, 30, 40, 50])

print('A Series of integers:')
print(my_series)
print("\n")

# Create a Series of strings with custom index labels
my_series = pd.Series(['apple', 'banana', 'cherry', 'date', 'elderberry'], index=['a', 'b', 'c', 'd', 'e'])

print('A Series of strings:')
print(my_series)

# %% [markdown]
# ## Dataframes
#
# A DataFrame is a **two-dimensional table** that can hold data of **multiple** types, similar to a spreadsheet or a SQL table.
#
# A DataFrame consists of rows and columns, where each column can have a different data type (e.g., integer, float, string, boolean, datetime).

# %%
# Create a DataFrame from a dictionary of lists
data = {'name': ['Alice', 'Bob', 'Charlie', 'David', 'Emily'],
        'age': [25, 30, 35, 40, 45],
        'city': ['New York', 'Paris', 'London', 'Tokyo', 'Sydney']}

df = pd.DataFrame(data)

print('A DataFrame created from a dictionary where keys are strings and values are lists of strings or ints:')
print(df)

# %%
# Create a DataFrame with custom row and column labels
data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
df = pd.DataFrame(data, index=['row1', 'row2', 'row3'], columns=['col1', 'col2', 'col3'])

print('A DataFrame created from a 2D array with custom headers of rows and columns')
print(df)

# %% [markdown]
# # Dataframe Metadata
#
# Pandas includes a wide range of built-in functions for working with these data structures, including grouping, aggregating, merging, and reshaping data.

# %%
data = {'name': ['Alice', 'Bob', 'Charlie', 'David', 'Emily'],
        'age': [25, 30, 35, 40, 45],
        'city': ['New York', 'Paris', 'London', 'Tokyo', 'Sydney']}

df = pd.DataFrame(data)
 
print('Number of rows and columns in the DataFrame:')
print(df.shape)
print("-"*100)

print('Description of Indices:')
print(df.index)
print("-"*100)

print('Description of Columns:')
print(df.columns)
print("-"*100)

print('Information about the DataFrame:')
print(df.info())
print("-"*100)

print("Number of non-NA values")
print(df.count()) 
print("-"*100)

print("Descriptive statistics for the numerical columns")
print(df.describe())

# %% [markdown]
# # Question 1
#
# For this exercise, we have created a Pandas dataframe for a few animal classes. Use Pandas functions and dataframe properties to figure out:
#
# (a) How many unique classes are there in the dataframe `df`?
# (b) How many samples per class are there in the datagrame `df`?

# %%
np.random.seed(0)
random.seed(0)

# Define the class labels and their corresponding frequencies
class_labels = ['Dog', 'Cat', 'Horse', 'Tiger', 'Lion', 'Zebra', 'Giraffe', 'Monkey', 'Rabbit', 'Bear']
class_freqs = [random.randint(1, 1000), random.randint(1, 1000), random.randint(1, 1000), random.randint(1, 1000), random.randint(1, 1000) ,random.randint(1, 1000), random.randint(1, 1000), random.randint(1, 1000), random.randint(1, 1000), random.randint(1, 1000)]

# Initialize an empty DataFrame
df = pd.DataFrame()

# Loop through each class label and add random samples to the DataFrame
for i, class_label in enumerate(class_labels):
    num_samples = class_freqs[i]
    data = np.random.randn(num_samples, 5) # generate random data
    label = [class_label] * num_samples # repeat the class label
    df_class = pd.DataFrame(data, columns=['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4', 'Feature 5'])
    df_class['Class'] = label
    df = pd.concat([df, df_class], ignore_index=True)

# Shuffle the rows of the DataFrame
df = df.sample(frac=1).reset_index(drop=True)

# Print the first 10 rows of the DataFrame
print(df.head(10))

# %% [markdown]
# ## Answer 1

# %%
classes = # Find unique classes

print('Total unique classes:')
print(classes)
print('')

for animal in classes:
  # Create a boolean mask for the current animal class
  mask = # Create mask here

  # Apply the mask to the DataFrame to get a dataframe with only rows matching the current animal class
  animal_df = # Apply mask

  # Count the number of rows (samples) in this subset
  num_samples = # Fine number of rows

  # num_samples = len(df[df["Class"]==animal]) # a one-line equivalent to the above
  print("Number of entities in class " + animal +" is: "+ str(num_samples))

# %% [markdown]
# # Question 2
#
# In the above Question 1 dataframe `df`, for each class, find out a sample which has lowest value of `Feature 2`.

# %% [markdown]
# ## Answer 2

# %%
min_values = # Find lowest value 
print(min_values)

# %% [markdown]
# # A Quick Detour into Deep Learning Applications - Image Synthesis

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# "Image synthesis is the process of artificially generating images that contain some particular desired content. It is analogous to the inverse of the classification problem: generating an image that contains the visual contents that are associated with a specific label."
#
# Source: Biomedical Information Technology, Second Edition by Kumar et al.
#
# See also: https://github.com/altryne/awesome-ai-art-image-synthesis

# %% [markdown]
# # Accessing Elements
#
# In Pandas, you can access individual elements, rows, or columns in a DataFrame using various methods.

# %% [markdown]
# ## Get one Element

# %%
series = pd.Series([10, 20, 30, 40, 50])

print('Fourth element of the Series: ', series[3])

# %% [markdown]
# ## Get a subset of the DataFrame

# %%
data = {'name': ['Alice', 'Bob', 'Charlie', 'David', 'Emily'],
        'age': [25, 30, 35, 40, 45],
        'city': ['New York', 'Paris', 'London', 'Tokyo', 'Sydney']}

df = pd.DataFrame(data)

print('Second and Third rows of the DataFrame:\n\n', df[1:3])

# %% [markdown]
# ## Index by Position

# %%
print('First row and first column:\n')
print(df.iloc[[0],[0]])

# %%
print('First row and first column:\n')
print(df.iat[0, 0])

# %% [markdown]
# ## Index by Label

# %%
print('Selecting values by row and column index/name:\n')
print(df.loc[[0], ['city']])

# %%
print('Selecting values by row and column index/name:\n')
print(df.at[0,'city'])

# %% [markdown]
# ## Boolean Indexing

# %%
print('Subset of the Series where the elements are not > 30:\n')
series[~(series > 30)]

# %%
print('Subset of the Series where the elements are < 20 and > 40:\n')
series[(series < 20) | (series > 40)]

# %%
 print('Subset of the DataFrame where the people\'s age is > 32:\n')
 df[df['age']>32]

# %% [markdown]
# ## Question 3
#
# From the given dataframe of dishes and their properties, get all the rows where a dish is `Sweet` and has calories `< 400`.

# %%
np.random.seed(0)
random.seed(0)

# Define the categories and their corresponding options
dish_names = ['Lasagna', 'Taco', 'Pizza', 'Burger', 'Salad', 'Stir Fry']
taste_options = ['Spicy', 'Sweet', 'Sour', 'Salty', 'Umami']
nutrient_options = ['Protein', 'Carbohydrates', 'Fat', 'Vitamin A', 'Vitamin C', 'Calcium', 'Iron']

# Initialize an empty DataFrame
df = pd.DataFrame()

# Loop through each sample and add random values for each column
for i in range(1000):
    dish = np.random.choice(dish_names)
    calories = np.random.randint(300, 1000)
    taste = np.random.choice(taste_options)
    nutrients = np.random.choice(nutrient_options, size=3, replace=False)
    df = pd.concat([df, pd.DataFrame({'Dish Name': dish, 'Calories': calories, 'Taste': taste, 'Nutrients': nutrients})], ignore_index=True)

# Print the resulting DataFrame
print(df.head())

# %% [markdown]
# ### Answer 3

# %%
# Filter the DataFrame by calories and taste
filtered_df = # Perform filter here

# Print the resulting DataFrame
print(filtered_df)

# %% [markdown]
# ## Question 4
#
# From the above dishes information dataframe `df`, print a sub-dataframe containing all the rows from #100 to #120 except row #115 and columns `Dish Name` and `Nutrients`.

# %% [markdown]
# ### Answer 4

# %%
# Slice the DataFrame by row and column indices
sub_df = # Perform drop here

# Drop the 'Calories' column
sub_df = # Perform drop
# Drop the 'Taste' column
sub_df = # Perform drop

# Drop row #115
sub_df = # Perform drop

# Print the resulting DataFrame
print(sub_df)

# %% [markdown]
# # Modifying Elements

# %%
print('Changing the series value:\n')

print('Before changing:')
print(series)
print('\n')
series[2] = 99
print('After changing:')
print(series)

# %%
print('Deleting the series value:\n')

print('Before deletion:')
print(series)

series = series.drop([2])
print('After deletion:')
print(series)

# %% [markdown]
# # Sorting and Ranking

# %%
print('Sort by labels along an axis')
print(df.sort_index(ascending=False))
print('-'*100)
print('\n')

print('Sort by the values along an axis')
print(df.sort_values(by = 'Calories')) 
print('-'*100)
print('\n')

print('Assign ranks to entries')
print(df.rank())

# %% [markdown]
# ## Question 5
#
# Sort the dataframe given below, first sort the dataframe in ascending order by `City` name. For the same `City` name, sort the `Province` name in descending order.

# %%
np.random.seed(0)
random.seed(0)

# Define a list of cities and provinces
cities = ['Toronto', 'Vancouver', 'Montreal', 'Calgary', 'Ottawa', 'Edmonton', 'Winnipeg', 'Quebec City', 'Hamilton', 'Halifax']
provinces = ['Ontario', 'British Columbia', 'Quebec', 'Alberta', 'Manitoba', 'Saskatchewan', 'Nova Scotia', 'New Brunswick', 'Prince Edward Island', 'Newfoundland and Labrador']

# Initialize an empty DataFrame
df = pd.DataFrame()

# Loop through each sample and add random city and province names
for i in range(500):
    city = random.choice(cities)
    province = random.choice(provinces)
    df = pd.concat([df, pd.DataFrame({'City': [city], 'Province': [province]})], ignore_index=True)

# Print the resulting DataFrame
print(df.head(10))

# %% [markdown]
# ### Answer 5

# %%
sorted_df = # Sort here

print(sorted_df)

# %% [markdown]
# # Upload this Colab Notebook to your Github repository. Also add your *reflections* on today's learning in README.md

# %% [markdown]
# Reference:
#
# https://res.cloudinary.com/dyd911kmh/image/upload/v1676302204/Marketing/Blog/Pandas_Cheat_Sheet.pdf
